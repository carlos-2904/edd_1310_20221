# %% [markdown]
# <a href="https://colab.research.google.com/github/carlos-2904/edd_1310_20221/blob/master/15octubre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mi_modulo import sumar as sm,

print(sm(4,7))
print(dividir(14,7))

# %%
import mi_modulo as patito

print(patito.sumar( 4, 6))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5de5e4ef61e9> in <module>()
# ----> 1 import mi_modulo as patito
#       2
#       3 print(patito.sumar( 4, 6))
#
# ModuleNotFoundError: No module named 'mi_modulo'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from joke_generator import generate

generate ()
# Out:
# 'What do you get hanging from Apple trees? Sore arms.'

# %% [markdown]
# # archivos
#
# - opne( str , str)
#   1. Nombre o ruta del archivo
#   2. dos caracteres
#     - modo de apertura del archivo ( r , w , a apen si y solo si el archivo existe , x si solo si el archivo no existe)
#     - Formato del archivo (t o b)

# %% [markdown]
# # Nueva sección

# %%
archivo = open("saludo.txt","wt") 
archivo.write("Hola mundo \n ola k hace")
archivo.close()

# %%
 otro = open('./sample_data/anscombe.json','rt')
 datos = otro.read()
 #print(datos)
 otro.close()

 #arch = open('Frutas.txt','rt')
 data = 'ppp'
 while (data != ''):
  # data = arch.readline()
   print(data)

arch.close()
arch = open('Frutas.txt','rt')
list_Frutas = arch.readline()
print(list_Frutas)
arch.close()
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ppp
# ...

# %%
help(otro)
# Out:
# Help on TextIOWrapper object:
#
# class TextIOWrapper(_TextIOBase)
#  |  Character and line based layer over a BufferedIOBase object, buffer.
#  |
#  |  encoding gives the name of the encoding that the stream will be
#  |  decoded or encoded with. It defaults to locale.getpreferredencoding(False).
#  |
#  |  errors determines the strictness of encoding and decoding (see
#  |  help(codecs.Codec) or the documentation for codecs.register) and
#  |  defaults to "strict".
#  |
#  |  newline controls how line endings are handled. It can be None, '',
#  |  '\n', '\r', and '\r\n'.  It works as follows:
#  |
#  |  * On input, if newline is None, universal newlines mode is
#  |    enabled. Lines in the input can end in '\n', '\r', or '\r\n', and
#  |    these are translated into '\n' before being returned to the
#  |    caller. If it is '', universal newline mode is enabled, but line
#  |    endings are returned to the caller untranslated. If it has any of
# ...
